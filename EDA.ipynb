# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhoshkumar5655/datasciencelearning/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# eda => exploratory data analysis
# it is the process of understanding and analyzing data before building models
# #we need to check
# what data is present
# is there any missing values ?
# is there any duplicates
# what patterns exist
# what columns are important
# is the dataset is balanced or not
# wirthout eda
# we may train model on wrong data
# missing values creates errors
# outlers can reduce accuracy
# 1,2,3,4,45,6,6,10,20,30,10,40,100000

# %%
#complete eda steps

# %%
#import libraries

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#datasetloading
df = sns.load_dataset("titanic")

# %%
#view data set
df.head() #show first 5 rows

# %%
df.tail() #last 5 rows

# %%
df.sample()

# %%
#understanding dataset structure
df.shape #it will tell how many rows and columns
# Out:
# (891, 15)

# %%
df.columns #it will give how many columns

# %%
# df.info
# show datatypes, non null values, data type
df.info()

# %%
df.dtypes #showing dtypes

# %%
# statistical summary
# mean
# min
# max
# variance
df.describe()

# %%
#we have to check missing values
df.isnull()

# %%
df.isnull().sum()

# %%
#we have to fill that values by using fillna method (mean, mode, median, logoc)

# %%
#we have to delete those rows and columns by using drop

# %%
#we have to check duplicate records
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
# if we have duplicate records jut we will remove those records drop

# %%
#correlation analysis
df.corr(numeric_only=True)

# %%
#outliers - visualiszation
#data set balanced or imabalanced
#faeture engineering
21-09-2002 => 21 09 2002

# %%
#dataset reading
#info
#stat analysis
#missing values
#filing missing
#drop
#duplicates
#corrleation
#outliers
# dataset balanced or imbalanced
# faeture engineering

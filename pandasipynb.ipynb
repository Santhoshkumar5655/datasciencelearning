# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhoshkumar5655/datasciencelearning/blob/main/pandasipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
#series
arr = np.array([10,20,30,40,50])
marks = pd.Series(arr)
print(marks)
print(marks[0])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 10

# %%
marks = pd.Series(
    [10,20,30],
    index = ["math","phy","chem"]
)
print(marks)
print(marks["math"])
print(marks.shape)
print(marks.size)
print(marks.dtype)
print(marks.values)
print(marks.index)
# Out:
# math    10
# phy     20
# chem    30
# dtype: int64
# 10
# (3,)
# 3
# int64
# [10 20 30]
# Index(['math', 'phy', 'chem'], dtype='object')

# %%
# => 2,4,68,14
numbers = [1,2,34,7]
result = []
for i in numbers:
  result.append(i*2)
print(result)
# Out:
# [2, 4, 68, 14]

# %%
# vectorized opeartion means applying one opeartion to all elements automatically without writing loops
numbers = [1,2,34,7]
arr = np.array(numbers)
print(arr*2)
# Out:
# [ 2  4 68 14]

# %%
data = pd.Series([10,20,30,40, np.nan, 50])
# [10,20,30,40, np.nan, 50]
print(data.isnull()) # if i want to know the missing values i will use  is null method
print(data.fillna(10))
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# dtype: bool
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    10.0
# 5    50.0
# dtype: float64

# %%
#dataframe
data = {
    "name": ["lahari", "jagadeesh", "saikiran", "swathi"],
    "marks": [60,61,70,71],
    "city": ["vij", "bang", "bangkok","london"]
}
df = pd.DataFrame(data)
print(df)
print(df.shape)
print(df.size)
print(df.columns)
print(df.dtypes)
print(df.index)
# Out:
#         name  marks     city
# 0     lahari     60      vij
# 1  jagadeesh     61     bang
# 2   saikiran     70  bangkok
# 3     swathi     71   london
# (4, 3)
# 12
# Index(['name', 'marks', 'city'], dtype='object')
# name     object
# marks     int64
# city     object
# dtype: object
# RangeIndex(start=0, stop=4, step=1)

# %%
df["Grade"] = ["B", "B", "A","A"]
print(df)
# Out:
#         name  marks     city Grade
# 0     lahari     60      vij     B
# 1  jagadeesh     61     bang     B
# 2   saikiran     70  bangkok     A
# 3     swathi     71   london     A

# %%
df["marks"] = df["marks"] + 20
print(df)
df.drop("city", axis=1)
# Out:
#         name  marks     city Grade
# 0     lahari     80      vij     B
# 1  jagadeesh     81     bang     B
# 2   saikiran     90  bangkok     A
# 3     swathi     91   london     A
#         name  marks Grade
# 0     lahari     80     B
# 1  jagadeesh     81     B
# 2   saikiran     90     A
# 3     swathi     91     A

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/datsetsfordatasciencebytexl/student_dataset_20rows.csv")
print(df)
# Out:
#     Student_ID     Name  Age            Course  Marks         City
# 0          101      Ram   25            Pandas     90   Vijayawada
# 1          102     Ravi   23             NumPy     81    Hyderabad
# 2          103     Sita   21            Python     80      Chennai
# 3          104    Kiran   21      Data Science     98    Bangalore
# 4          105      Anu   20            Pandas     70       Mumbai
# 5          106    Rahul   22               SQL     82        Delhi
# 6          107    Sneha   25     Deep Learning     79         Pune
# 7          108    Arjun   22  Machine Learning     70      Kolkata
# 8          109    Pooja   20            Python     95        Vizag
# 9          110   Vikram   20               SQL     72     Tirupati
# 10         111    Divya   23     Deep Learning     94     Warangal
# 11         112     Ajay   21            Python     84       Guntur
# 12         113  Keerthi   21             NumPy     74      Nellore
# ...

# %%
df = pd.read_excel("/content/drive/MyDrive/datsetsfordatasciencebytexl/student_dataset_20rows.xlsx")
print(df)

# %%
df = pd.read_json("/content/drive/MyDrive/datsetsfordatasciencebytexl/student_dataset_20rows.json")
print(df)

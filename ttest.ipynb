# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhoshkumar5655/datasciencelearning/blob/main/ttest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a school principal is saying my college average is 80
import numpy as np
from scipy.stats import ttest_1samp
#taking sample
marks = [82,85,78,90,88,79,84,86,87,83]
#ho = 80
t_statistic, p_value = ttest_1samp(marks,80)
print(np.mean(marks))
print("tstatistic", t_statistic)
print("p_vale", p_value)
alpha = 0.05
if p_value<0.05:
  print("reject ho")
else:
    print("fail to reject")

# %%
marks = [79,80,81,82,78,80,81,79,80,80]
# ho= 80
t_stat,p_value = ttest_1samp(marks,80)
print(np.mean(marks))
print("t_stat", t_stat)
print("p_value", p_value)
alpha = 0.05
if p_value<0.05:
  print("reject ho")
else:
  print("failed to reject")

# %%
from scipy.stats import ttest_ind
import numpy as np
old_method_marks = [70,75,72,68,74,71,69,73]
new_method_marks = [78,80,82,77,79,81,83,80]
# Ho old_mean = new_mean
print("old method mean", np.mean(old_method_marks))
print("new method mean",np.mean(new_method_marks))
t_stat, p_value = ttest_ind(old_method_marks, new_method_marks)
print("t_stat", t_stat)
print("p_value",p_value)
alpha = 0.05
if p_value<alpha:
  print("rejcet ho")
else:
  print("failed to reject")
# Out:
# old method mean 71.5
# new method mean 80.0
# t_stat -7.602631123499284
# p_value 2.465359356807103e-06
# rejcet ho
